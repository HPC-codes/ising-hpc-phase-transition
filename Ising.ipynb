# %%
# !git clone https://github.com/HPC-codes/ising-hpc-phase-transition.git
# Out:
# Cloning into 'ising-hpc-phase-transition'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 44 (delta 20), reused 15 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 19.27 KiB | 9.63 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %%
# !apt-get install tree -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 0s (431 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 126308 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# !tree
# Out:
# .
# ├── ising-hpc-phase-transition
# │   ├── Makefile
# │   ├── README.md
# │   └── src
# │       ├── graf.py
# │       ├── graf.py~
# │       ├── main.cpp
# │       ├── SquareLattice.cpp
# │       ├── SquareLattice.h
# │       ├── wolf.cpp
# │       └── wolf.h
# └── sample_data
#     ├── anscombe.json
#     ├── california_housing_test.csv
#     ├── california_housing_train.csv
#     ├── mnist_test.csv
#     ├── mnist_train_small.csv
#     └── README.md
#
# 3 directories, 15 files

# %%
# %cd /content/ising-hpc-phase-transition
# !make
# Out:
# /content/ising-hpc-phase-transition
# make: Nothing to be done for 'all'.

# %%
# !./ising_simulation 32 1.8 2.6 0.1 10000 --save-time
# Out:
# SIMULACION DEL MODELO ISING 2D
# Algoritmo de Wolff - Transición de fase
# ...
#
# Iniciando simulación Ising 2D (Algoritmo Wolff)
# ...
# Tamaño de red: 32x32 (1024 spines)
# Rango de temperatura: [1.5,3] paso 0.1
# Iteraciones por temperatura: 5000
# Guardar evolución temporal: SI
# ...
#
# T =   1.5  |M| = 0.986719  E = -1.95312  χ = 0.030599  C = 1.93405e-07  U = 0.666605  [8s]
# T =   1.6  |M| = 0.973437  E = -1.91016  χ = 0.0660324  C = 3.21324e-07  U = 0.666521  [7s]
# T =   1.7  |M| = 0.966797  E = -1.89141  χ = 0.0431913  C = 2.19376e-07  U = 0.666565  [7s]
# T =   1.8  |M| = 0.959375  E = -1.86563  χ = 0.140957  C = 7.48004e-07  U = 0.666306  [7s]
# T =   1.9  |M| = 0.935156  E = -1.81562  χ = 0.164024  C = 2.0542e-07  U = 0.666201  [6s]
# T =     2  |M| = 0.921484  E = -1.76094  χ = 0.157349  C = 6.81612e-07  U = 0.666186  [7s]
# T =   2.1  |M| = 0.879687  E = -1.66953  χ = 0.519787  C = 6.79327e-07  U = 0.664788  [5s]
# ...

# %%
# !python /content/ising-hpc-phase-transition/src/graf.py /content/ising-hpc-phase-transition/ising_results_L32.csv
# Out:
# ...
#            VISUALIZACIÓN DE RESULTADOS - MODELO DE ISING 2D
# ...
#
# PARÁMETROS DE SIMULACIÓN:
# • Tamaño de red: 32×32
# • Constante de acoplamiento (J): 1.0000
# • Rango de temperatura: [1.0000, 3.0000]
# • Iteraciones por temperatura: 1,000
# • Puntos de datos: 16
# • Estilo gráfico seleccionado: seaborn-v0_8-paper
#
# GENERANDO GRÁFICOS...
# /content/ising-hpc-phase-transition/src/graf.py:252: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.savefig(output_file)
# findfont: Generic family 'serif' not found because none of the following families were found: Times New Roman, Computer Modern Roman
# findfont: Generic family 'serif' not found because none of the following families were found: Times New Roman, Computer Modern Roman
# findfont: Generic family 'serif' not found because none of the following families were found: Times New Roman, Computer Modern Roman
# ...

# %%
# !lscpu
# Out:
# Architecture:             x86_64
#   CPU op-mode(s):         32-bit, 64-bit
#   Address sizes:          46 bits physical, 48 bits virtual
#   Byte Order:             Little Endian
# CPU(s):                   2
#   On-line CPU(s) list:    0,1
# Vendor ID:                GenuineIntel
#   Model name:             Intel(R) Xeon(R) CPU @ 2.20GHz
#     CPU family:           6
#     Model:                79
#     Thread(s) per core:   2
#     Core(s) per socket:   1
#     Socket(s):            1
#     Stepping:             0
#     BogoMIPS:             4399.99
#     Flags:                fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge m
#                           ca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht sysc
#                           all nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xt
#                           opology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq
#                            ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt
# ...
